# %%
import tensorflow as tf
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.3007 - accuracy: 0.9126
# Epoch 2/5
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1445 - accuracy: 0.9567
# Epoch 3/5
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.1076 - accuracy: 0.9673
# Epoch 4/5
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.0883 - accuracy: 0.9732
# Epoch 5/5
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0753 - accuracy: 0.9767
# ...
